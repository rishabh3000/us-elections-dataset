# %%
import opendatasets as od
dataset_url = 'https://www.kaggle.com/tunguz/us-elections-dataset'
od.download('https://www.kaggle.com/tunguz/us-elections-dataset')
# Out:
# Skipping, found downloaded files in ".\us-elections-dataset" (use force=True to force download)

# %%
data_dir = './us-elections-dataset'
import os
os.listdir(data_dir)
# Out:
# ['.ipynb_checkpoints']

# %%
import pandas as pd

# %%
data_set=pd.read_csv("1976-2020-president.csv")

# %%
data_set.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic        office  \
# 0  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 1  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 2  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 3  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 4  1976  ALABAMA       AL           1         63        41  US PRESIDENT
#
#                  candidate              party_detailed writein  \
# 0            CARTER, JIMMY                    DEMOCRAT   False
# 1             FORD, GERALD                  REPUBLICAN   False
# 2           MADDOX, LESTER  AMERICAN INDEPENDENT PARTY   False
# 3  BUBAR, BENJAMIN ""BEN""                 PROHIBITION   False
# 4                HALL, GUS         COMMUNIST PARTY USE   False
#
#    candidatevotes  totalvotes   version  notes party_simplified
# 0          659170     1182850  20210113    NaN         DEMOCRAT
# ...

# %%
data_set2=pd.read_csv("1976-2020-senate.csv", encoding="ISO-8859–1") #utf-8, ISO-8859–1

# %%
data_set2.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic     office  \
# 0  1976  ARIZONA       AZ           4         86        61  US SENATE
# 1  1976  ARIZONA       AZ           4         86        61  US SENATE
# 2  1976  ARIZONA       AZ           4         86        61  US SENATE
# 3  1976  ARIZONA       AZ           4         86        61  US SENATE
# 4  1976  ARIZONA       AZ           4         86        61  US SENATE
#
#     district stage  special            candidate party_detailed  writein  \
# 0  statewide   gen    False          SAM STEIGER     REPUBLICAN    False
# 1  statewide   gen    False  WM. MATHEWS FEIGHAN    INDEPENDENT    False
# 2  statewide   gen    False     DENNIS DECONCINI       DEMOCRAT    False
# 3  statewide   gen    False        ALLAN NORWITZ    LIBERTARIAN    False
# 4  statewide   gen    False            BOB FIELD    INDEPENDENT    False
#
#     mode  candidatevotes  totalvotes  unofficial   version party_simplified
# ...

# %%
data_set.info()
data_set2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4287 entries, 0 to 4286
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              4287 non-null   int64
#  1   state             4287 non-null   object
#  2   state_po          4287 non-null   object
#  3   state_fips        4287 non-null   int64
#  4   state_cen         4287 non-null   int64
#  5   state_ic          4287 non-null   int64
#  6   office            4287 non-null   object
#  7   candidate         4000 non-null   object
#  8   party_detailed    3831 non-null   object
#  9   writein           4284 non-null   object
#  10  candidatevotes    4287 non-null   int64
#  11  totalvotes        4287 non-null   int64
#  12  version           4287 non-null   int64
#  13  notes             0 non-null      float64
#  14  party_simplified  4287 non-null   object
# dtypes: float64(1), int64(7), object(7)
# memory usage: 502.5+ KB
# ...

# %%
data_set.isna().any()
# Out:
# year                False
# state               False
# state_po            False
# state_fips          False
# state_cen           False
# state_ic            False
# office              False
# candidate            True
# party_detailed       True
# writein              True
# candidatevotes      False
# totalvotes          False
# version             False
# notes                True
# party_simplified    False
# dtype: bool

# %%
data_set.isnull().any()
# Out:
# year                False
# state               False
# state_po            False
# state_fips          False
# state_cen           False
# state_ic            False
# office              False
# candidate            True
# party_detailed       True
# writein              True
# candidatevotes      False
# totalvotes          False
# version             False
# notes                True
# party_simplified    False
# dtype: bool

# %%
data_set["version"].unique()
# Out:
# array([20210113], dtype=int64)

# %%
missing_data=data_set.isnull()

# %%
missing_data.head().all()
# Out:
# year                False
# state               False
# state_po            False
# state_fips          False
# state_cen           False
# state_ic            False
# office              False
# candidate           False
# party_detailed      False
# writein             False
# candidatevotes      False
# totalvotes          False
# version             False
# notes                True
# party_simplified    False
# dtype: bool

# %%
missing_data.columns
# Out:
# Index(['year', 'state', 'state_po', 'state_fips', 'state_cen', 'state_ic',
#        'office', 'candidate', 'party_detailed', 'writein', 'candidatevotes',
#        'totalvotes', 'version', 'notes', 'party_simplified'],
#       dtype='object')

# %%
missing_data.columns.value_counts()
# Out:
# year                1
# totalvotes          1
# state_cen           1
# state               1
# state_ic            1
# state_fips          1
# writein             1
# version             1
# office              1
# notes               1
# party_detailed      1
# party_simplified    1
# state_po            1
# candidate           1
# candidatevotes      1
# dtype: int64

# %%
missing_data.columns.values.tolist()
# Out:
# ['year',
#  'state',
#  'state_po',
#  'state_fips',
#  'state_cen',
#  'state_ic',
#  'office',
#  'candidate',
#  'party_detailed',
#  'writein',
#  'candidatevotes',
#  'totalvotes',
#  'version',
#  'notes',
#  'party_simplified']

# %%
for col in missing_data.columns.values.tolist():
    print(missing_data[col].value_counts())
    print("\n")
# Out:
# False    4287
# Name: year, dtype: int64
#
#
# False    4287
# Name: state, dtype: int64
#
#
# False    4287
# Name: state_po, dtype: int64
#
#
# False    4287
# Name: state_fips, dtype: int64
#
#
# False    4287
# Name: state_cen, dtype: int64
#
#
# False    4287
# Name: state_ic, dtype: int64
#
#
# False    4287
# Name: office, dtype: int64
#
#
# False    4000
# True      287
# Name: candidate, dtype: int64
#
#
# False    3831
# True      456
# Name: party_detailed, dtype: int64
#
#
# False    4284
# True        3
# Name: writein, dtype: int64
#
#
# False    4287
# Name: candidatevotes, dtype: int64
#
#
# False    4287
# Name: totalvotes, dtype: int64
#
#
# False    4287
# Name: version, dtype: int64
#
#
# True    4287
# Name: notes, dtype: int64
#
#
# False    4287
# Name: party_simplified, dtype: int64

# %%
data_set.loc[:,missing_data.any()].head()
# Out:
#                  candidate              party_detailed writein  notes
# 0            CARTER, JIMMY                    DEMOCRAT   False    NaN
# 1             FORD, GERALD                  REPUBLICAN   False    NaN
# 2           MADDOX, LESTER  AMERICAN INDEPENDENT PARTY   False    NaN
# 3  BUBAR, BENJAMIN ""BEN""                 PROHIBITION   False    NaN
# 4                HALL, GUS         COMMUNIST PARTY USE   False    NaN

# %%
missing_data.drop("notes",axis=1,inplace=True)

# %%
missing_data.head()
# Out:
#     year  state  state_po  state_fips  state_cen  state_ic  office  candidate  \
# 0  False  False     False       False      False     False   False      False
# 1  False  False     False       False      False     False   False      False
# 2  False  False     False       False      False     False   False      False
# 3  False  False     False       False      False     False   False      False
# 4  False  False     False       False      False     False   False      False
#
#    party_detailed  writein  candidatevotes  totalvotes  version  \
# 0           False    False           False       False    False
# 1           False    False           False       False    False
# 2           False    False           False       False    False
# 3           False    False           False       False    False
# 4           False    False           False       False    False
#
#    party_simplified
# 0             False
# 1             False
# 2             False
# 3             False
# ...

# %%
missing_data
# Out:
#        year  state  state_po  state_fips  state_cen  state_ic  office  \
# 0     False  False     False       False      False     False   False
# 1     False  False     False       False      False     False   False
# 2     False  False     False       False      False     False   False
# 3     False  False     False       False      False     False   False
# 4     False  False     False       False      False     False   False
# ...     ...    ...       ...         ...        ...       ...     ...
# 4282  False  False     False       False      False     False   False
# 4283  False  False     False       False      False     False   False
# 4284  False  False     False       False      False     False   False
# 4285  False  False     False       False      False     False   False
# 4286  False  False     False       False      False     False   False
#
#       candidate  party_detailed  writein  candidatevotes  totalvotes  version  \
# ...

# %%
data_set.drop("notes",axis=1,inplace=True)

# %%
data_set
# Out:
#       year    state state_po  state_fips  state_cen  state_ic        office  \
# 0     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 1     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 2     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 3     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 4     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# ...    ...      ...      ...         ...        ...       ...           ...
# 4282  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4283  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4284  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4285  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4286  2020  WYOMING       WY          56         83        68  US PRESIDENT
#
# ...

# %%
data_set["writein"].unique()
# Out:
# array([False, True, nan], dtype=object)

# %%
data_set["writein"].value_counts()
# Out:
# False    3807
# True      477
# Name: writein, dtype: int64

# %%
data_set["writein"].replace("nan","False",inplace=True)

# %%
data_set["writein"].unique()
# Out:
# array([False,  True])

# %%
data_set["writein"].value_counts()
# Out:
# False    3611
# True      143
# Name: writein, dtype: int64

# %%
data_set.isnull().any()
# Out:
# year                False
# state               False
# state_po            False
# state_fips          False
# state_cen           False
# state_ic            False
# office              False
# candidate            True
# party_detailed       True
# writein             False
# candidatevotes      False
# totalvotes          False
# version             False
# party_simplified    False
# dtype: bool

# %%
data_set["candidate"].unique()
# Out:
# array(['CARTER, JIMMY', 'FORD, GERALD', 'MADDOX, LESTER',
#        'BUBAR, BENJAMIN ""BEN""', 'HALL, GUS', 'MACBRIDE, ROGER', nan,
#        'MCCARTHY, EUGENE ""GENE""', 'CAMEJO, PETER',
#        'ANDERSON, THOMAS J.', 'WRIGHT, MARGARET', 'LAROUCHE, LYNDON, JR.',
#        'SCATTERING', 'OTHER', 'JULIUS ""JULES"", LEVIN', 'ZEIDLER, FRANK',
#        'REAGAN, RONALD', 'ANDERSON, JOHN B.', 'RARICK, JOHN',
#        'CLARK, EDWARD ""ED""', 'DEBERRY, CLIFTON', 'MCREYNOLDS, DAVID',
#        'COMMONER, BARRY', 'GRISWOLD, DEIRDRE', 'SMITH, MAUREEN',
#        'PULLEY, ANDREW', 'GREAVES, PERCY L, JR.', 'SHELTON, FRANK, JR.',
#        'MCCORMACK, ELLEN', 'LYNEN, KURT', 'GAHRES, WILLIAM ""BILL""',
#        'WENDELKEN, MARTIN E.', 'MCLAIN, HARLEY', 'CONGRESS, RICHARD',
#        'MONDALE, WALTER', 'BERGLAND, DAVID', 'RICHARDS, BOB',
#        'MASON, MELVIN', 'SERRETTE, DENNIS', 'JOHNSON, SONIA',
#        'DODGE, EARL', 'LOWERY, ARTHUR', 'DENNIS, DELMAR', 'HOLMES, LARRY',
# ...

# %%
data_set["candidate"].value_counts()
# Out:
# NADER, RALPH               137
# OTHER                      106
# BUSH, GEORGE H.W.          105
# REAGAN, RONALD             104
# BUSH, GEORGE W.            104
#                           ...
# CUOMO, ANDREW                1
# WEINSTEIN, KARYNN KRILL      1
# CHRISTENSEN, WILL            1
# YOUNGKEIT, LOUIE G.          1
# KLOJZY, JEFFREY J.           1
# Name: candidate, Length: 270, dtype: int64

# %%
data_set.dropna(subset = ["candidate"], axis = 0, inplace = True)
data_set.reset_index(drop = True, inplace = True)

# %%
data_set["candidate"].value_counts()
# Out:
# NADER, RALPH               137
# OTHER                      106
# BUSH, GEORGE H.W.          105
# REAGAN, RONALD             104
# BUSH, GEORGE W.            104
#                           ...
# CUOMO, ANDREW                1
# WEINSTEIN, KARYNN KRILL      1
# CHRISTENSEN, WILL            1
# YOUNGKEIT, LOUIE G.          1
# KLOJZY, JEFFREY J.           1
# Name: candidate, Length: 270, dtype: int64

# %%
data_set["party_detailed"].unique()
# Out:
# array(['DEMOCRAT', 'REPUBLICAN', 'AMERICAN INDEPENDENT PARTY',
#        'PROHIBITION', 'COMMUNIST PARTY USE', 'LIBERTARIAN', 'INDEPENDENT',
#        'SOCIALIST WORKERS', 'AMERICAN', 'PEACE & FREEDOM', 'U.S. LABOR',
#        nan, 'SOCIALIST LABOR', 'AMERICAN PARTY OF IOWA',
#        'SOCIALIST U.S.A.', 'CONSERVATIVE', 'HUMAN RIGHTS', "MCCARTHY '76",
#        "PEOPLE'S", 'INTERNATIONAL DEVELOPMENT BANK',
#        'INDUSTRIAL GOVERNMENT PARTY', 'SOCIALIST', 'LIBERAL PARTY',
#        'FREE LIBERTARIAN', 'LABOR', 'CONSTITUTION PARTY',
#        'CONCERNED CITIZENS', 'STATESMAN', 'CITIZENS', 'WORKERS WORLD',
#        'NATIONAL UNITY CAMPAIGN', 'ANDERSON COALITION',
#        'NOMINATED BY PETITION', 'RESPECT FOR LIFE', 'RIGHT-TO-LIFE',
#        'MIDDLE CLASS CANDIDATE', 'DOWN WITH LAWYERS',
#        "NATURAL PEOPLE'S LEAGUE", 'POPULIST', 'ALLIANCE',
#        'UNITED SOVEREIGN CITIZENS', 'WORKERS LEAGUE', 'BIG DEAL PARTY',
# ...

# %%
data_set.dropna(subset=["party_detailed"],axis=0,inplace=True)
data_set.reset_index(drop=True,inplace=True)

# %%
data_set.isnull().any()
# Out:
# year                False
# state               False
# state_po            False
# state_fips          False
# state_cen           False
# state_ic            False
# office              False
# candidate           False
# party_detailed      False
# writein             False
# candidatevotes      False
# totalvotes          False
# version             False
# party_simplified    False
# dtype: bool

# %%
data_set2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3629 entries, 0 to 3628
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              3629 non-null   int64
#  1   state             3629 non-null   object
#  2   state_po          3629 non-null   object
#  3   state_fips        3629 non-null   int64
#  4   state_cen         3629 non-null   int64
#  5   state_ic          3629 non-null   int64
#  6   office            3629 non-null   object
#  7   district          3629 non-null   object
#  8   stage             3629 non-null   object
#  9   special           3629 non-null   bool
#  10  candidate         3206 non-null   object
#  11  party_detailed    3030 non-null   object
#  12  writein           3629 non-null   bool
#  13  mode              3629 non-null   object
#  14  candidatevotes    3629 non-null   int64
#  15  totalvotes        3629 non-null   int64
# ...

# %%
data_set2.isnull().any()
# Out:
# year                False
# state               False
# state_po            False
# state_fips          False
# state_cen           False
# state_ic            False
# office              False
# district            False
# stage               False
# special             False
# candidate            True
# party_detailed       True
# writein             False
# mode                False
# candidatevotes      False
# totalvotes          False
# unofficial          False
# version             False
# party_simplified    False
# dtype: bool

# %%
data_set2["party_detailed"].unique()
# Out:
# array(['REPUBLICAN', 'INDEPENDENT', 'DEMOCRAT', 'LIBERTARIAN',
#        'AMERICAN INDEPENDENT', 'PEACE AND FREEDOM', nan, 'AMERICAN',
#        'PROHIBITION', 'NONE', 'U.S. LABOR', 'SOCIALIST WORKERS',
#        'HUMAN RIGHTS', 'SOCIALIST LABOR', 'COMMUNIST',
#        'INDEPENDENT AMERICAN', 'LABOR', 'LA RAZA UNIDA', 'LIBERAL',
#        'CONSERVATIVE', 'CONSTITUTION', 'LIBERTY UNION',
#        'DEMOCRATIC SOCIALIST', 'NATIONAL STATESMAN',
#        'UNITED STATES PARTY', 'PUBLIC INTEREST INDEPENDENT', 'WORKERS',
#        'SOCIALIST', 'NATIONAL DEMOCRATIC PARTY OF ALABAMA', 'STATESMAN',
#        'PEOPLE BEFORE PROFITS', 'UNAFFILIATED-AMERICAN', 'CITIZENS',
#        'WORKERS WORLD', 'BY PETITION', 'NO PARTY', 'FREE LIBERTARIAN',
#        'RIGHT TO LIFE', 'WORKERS LEAGUE', 'NEW UNION',
#        'NOMINATED BY PETITION', 'REPEAL TF807 (HR4277-79)', 'GRASSROOTS',
#        'GOD, FAMILY, AND COUNTRY', 'CONSUMER', 'LABOR AND FARM',
#        'CONSTITUTIONALIST', 'TISCH INDEPENDENT CITIZENS',
# ...

# %%
data_set2.dropna(subset=["party_detailed"],axis=0,inplace=True)
data_set2.reset_index(drop=True,inplace=True)

# %%
data_set2.dropna(subset = ["candidate"], axis = 0, inplace = True)
data_set2.reset_index(drop = True, inplace = True)

# %%
data_set2.isnull().any()
# Out:
# year                False
# state               False
# state_po            False
# state_fips          False
# state_cen           False
# state_ic            False
# office              False
# district            False
# stage               False
# special             False
# candidate           False
# party_detailed      False
# writein             False
# mode                False
# candidatevotes      False
# totalvotes          False
# unofficial          False
# version             False
# party_simplified    False
# dtype: bool

# %%
import jovian

# %%
data_set2.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic     office  \
# 0  1976  ARIZONA       AZ           4         86        61  US SENATE
# 1  1976  ARIZONA       AZ           4         86        61  US SENATE
# 2  1976  ARIZONA       AZ           4         86        61  US SENATE
# 3  1976  ARIZONA       AZ           4         86        61  US SENATE
# 4  1976  ARIZONA       AZ           4         86        61  US SENATE
#
#     district stage  special            candidate party_detailed  writein  \
# 0  statewide   gen    False          SAM STEIGER     REPUBLICAN    False
# 1  statewide   gen    False  WM. MATHEWS FEIGHAN    INDEPENDENT    False
# 2  statewide   gen    False     DENNIS DECONCINI       DEMOCRAT    False
# 3  statewide   gen    False        ALLAN NORWITZ    LIBERTARIAN    False
# 4  statewide   gen    False            BOB FIELD    INDEPENDENT    False
#
#     mode  candidatevotes  totalvotes  unofficial   version party_simplified
# ...

# %%
data_set2["state"].unique()
# Out:
# array(['ARIZONA', 'CALIFORNIA', 'CONNECTICUT', 'DELAWARE', 'FLORIDA',
#        'HAWAII', 'INDIANA', 'MAINE', 'MARYLAND', 'MASSACHUSETTS',
#        'MICHIGAN', 'MINNESOTA', 'MISSISSIPPI', 'MISSOURI', 'MONTANA',
#        'NEBRASKA', 'NEVADA', 'NEW JERSEY', 'NEW MEXICO', 'NEW YORK',
#        'NORTH DAKOTA', 'OHIO', 'PENNSYLVANIA', 'RHODE ISLAND',
#        'TENNESSEE', 'TEXAS', 'UTAH', 'VERMONT', 'VIRGINIA', 'WASHINGTON',
#        'WEST VIRGINIA', 'WISCONSIN', 'WYOMING', 'ALABAMA', 'ALASKA',
#        'ARKANSAS', 'COLORADO', 'GEORGIA', 'IDAHO', 'ILLINOIS', 'IOWA',
#        'KANSAS', 'KENTUCKY', 'LOUISIANA', 'NEW HAMPSHIRE',
#        'NORTH CAROLINA', 'OKLAHOMA', 'OREGON', 'SOUTH CAROLINA',
#        'SOUTH DAKOTA'], dtype=object)

# %%
ad1.head()
# Out:
#      year           state state_po  state_fips  state_cen  state_ic  \
# 0    1976         ARIZONA       AZ           4         86        61
# 1    1976         ARIZONA       AZ           4         86        61
# 2    1976         ARIZONA       AZ           4         86        61
# 3    1976         ARIZONA       AZ           4         86        61
# 4    1976         ARIZONA       AZ           4         86        61
# ..    ...             ...      ...         ...        ...       ...
# 476  1982   WEST VIRGINIA       WV          54         55        56
# 483  1982         WYOMING       WY          56         83        68
# 488  1984          ALASKA       AK           2         94        81
# 499  1984         GEORGIA       GA          13         58        44
# 572  1984  SOUTH CAROLINA       SC          45         57        48
#
#         office   district stage  special            candidate party_detailed  \
# ...
